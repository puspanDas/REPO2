# %% [markdown]
# SERIES = 1D- array
# DATAFRAME = 2D-array

# %%
import pandas as pd
series_arr = pd.Series([1,2,5,5,3,4],index =[1,2,3,4,5,6])
print(series_arr)
list_1d =[1,3,4,6,7,8]
list_series =pd.Series(list_1d,index=[1,2,3,4,5,6])
df = pd.DataFrame({'series_arr':series_arr,'list_1d':list_series})
print(series_arr)
print(list_1d)
print(df)
# Out:
# 1    1
# 2    2
# 3    5
# 4    5
# 5    3
# 6    4
# dtype: int64
# 1    1
# 2    2
# 3    5
# 4    5
# 5    3
# 6    4
# dtype: int64
# [1, 3, 4, 6, 7, 8]
#    series_arr  list_1d
# 1           1        1
# 2           2        3
# 3           5        4
# 4           5        6
# 5           3        7
# 6           4        8

# %%
import pandas as pd
import matplotlib.pyplot as plt
df =pd.read_csv("iris.csv")
df
df.head()
print(df[["sepal.length","variety"]])
for col in ["petal.length","petal.width"]:
    print(df[col])
   
for i in range (len(df)):
    print(df.loc[i,"petal.length"],df.loc[i,"petal.width"])
# Out:
#      sepal.length    variety
# 0             5.1     Setosa
# 1             4.9     Setosa
# 2             4.7     Setosa
# 3             4.6     Setosa
# 4             5.0     Setosa
# ..            ...        ...
# 145           6.7  Virginica
# 146           6.3  Virginica
# 147           6.5  Virginica
# 148           6.2  Virginica
# 149           5.9  Virginica
#
# [150 rows x 2 columns]
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: petal.length, Length: 150, dtype: float64
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: petal.width, Length: 150, dtype: float64
# 1.4 0.2
# 1.4 0.2
# 1.3 0.2
# 1.5 0.2
# 1.4 0.2
# 1.7 0.4
# 1.4 0.3
# 1.5 0.2
# 1.4 0.2
# 1.5 0.1
# 1.5 0.2
# 1.6 0.2
# 1.4 0.1
# 1.1 0.1
# 1.2 0.2
# 1.5 0.4
# 1.3 0.4
# 1.4 0.3
# 1.7 0.3
# 1.5 0.3
# 1.7 0.2
# ...
